# %%
import sys
sys.path.append('audio_preproc')
import audio_preproc.fbtools
import audio_preproc.spectools
import numpy as np
from scipy.io import wavfile
from matplotlib import cm

# %%
[fs, w] = wavfile.read('audio_files/sn1_st1_sp1.wav')
w=w.astype(np.float)
print(fs)
# Out:
# 44100

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.plot(w)

# %%
pspec, e=audio_preproc.spectools.powspec(w, sr=fs, wintime=0.025, steptime=0.010, dither=1)

# %%
pspec.shape
# Out:
# (1025, 218)

# %%
plt.imshow(pspec, aspect='auto')

# %%
aspectrum, wts, freqs = audio_preproc.spectools.audspec(pspec, sr=fs, nfilts=80, fbtype='mel', minfreq=0, maxfreq=8000, sumpower=True, bwidth=1.0)

# %%
aspectrum.shape
wts.shape
# Out:
# (40, 1025)

# %%
plt.imshow(aspectrum**0.001, cmap=cm.RdBu_r, aspect='auto')
plt.gca().invert_yaxis()

# %%
freqs
# Out:
# array([    0.        ,    71.81847694,   143.63695388,   215.45543082,
#          287.27390776,   359.0923847 ,   430.91086164,   502.72933858,
#          574.54781552,   646.36629246,   718.1847694 ,   790.00324634,
#          861.82172327,   933.64020021,  1005.64528123,  1082.95576842,
#         1166.2096151 ,  1255.86372594,  1352.41013083,  1456.3786852 ,
#         1568.3399779 ,  1688.90846266,  1818.74583027,  1958.56463998,
#         2109.1322301 ,  2271.27492922,  2445.88259118,  2633.91347867,
#         2836.39952226,  3054.45198372,  3289.26755474,  3542.13492447,
#         3814.44185199,  4107.6827824 ,  4423.46704853,  4763.52770309,
#         5129.73102978,  5524.0867857 ,  5948.75923099,  6406.07900656,
#         6898.55592482,  7428.89274378])

# %%
wts.shape
# Out:
# (40, 1025)

# %%
plt.plot(freqs)
